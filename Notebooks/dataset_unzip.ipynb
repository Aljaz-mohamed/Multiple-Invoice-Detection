# %% [markdown]
# # Data Unzip code

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/ReceiptExtractor.v3i.yolov8 (1).zip' -d '/content/drive/MyDrive/Receipt dataset_seg'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/Receipt dataset_seg/train/labels/1005-receipt_jpg.rf.05455414de5089f17007751915d898bc.txt
#  extracting: /content/drive/MyDrive/Receipt dataset_seg/train/labels/1005-receipt_jpg.rf.0627f150c48e458687c44960e5dcee7b.txt
#  extracting: /content/drive/MyDrive/Receipt dataset_seg/train/labels/1005-receipt_jpg.rf.12ce3dbf7baa082a2f34cec11ccbe375.txt
#  extracting: /content/drive/MyDrive/Receipt dataset_seg/train/labels/1005-receipt_jpg.rf.271499b98cfe4a5e6374644ec843111a.txt
#  extracting: /content/drive/MyDrive/Receipt dataset_seg/train/labels/1005-receipt_jpg.rf.2b218a49185c21c2475be42158f3f017.txt
#  extracting: /content/drive/MyDrive/Receipt dataset_seg/train/labels/1005-receipt_jpg.rf.4206a311acb1ec6f6aa8578cfc300474.txt
#  extracting: /content/drive/MyDrive/Receipt dataset_seg/train/labels/1005-receipt_jpg.rf.701dcdf0d3abb1cd8eeb8f9cb73da3f6.txt
# ...
